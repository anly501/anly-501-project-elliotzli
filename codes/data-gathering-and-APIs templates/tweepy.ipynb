# %% [markdown]
# # Tweepy tutorial
#
# Contact: Dr. Hickman (GU) for questions
#
# **Modified from:** https://docs.tweepy.org/en/stable/getting_started.html
#
# `
# conda install -c conda-forge tweepy
# `

# %% [markdown]
# ### Authentication
#
# **content modified from:** https://docs.tweepy.org/en/v3.5.0/auth_tutorial.html
#
# Twitter requires all API requests to use OAuth for authentication.
#
# Tweepy supports oauth authentication. Authentication is handled by the tweepy.AuthHandler class.
#
# Tweepy tries to make OAuth as painless as possible for you.
#
# To begin the process we need to register our client application with Twitter.
#
# Create a new application and once you are done you should have your consumer token and secret.
#
# Keep these two handy, you’ll need them.
#
#
# **Read API keys from file**
#
# It is a good idea to save your API keys to a file that you can load into your scripts.
#
# * You can then "point" to that file anytime you need it
#
# * This keeps all your keys organized in one place, instead of being pasted into lots of different code scripts

# %%
import json 

# READ FILE
f = open("api-keys.json")
input=json.load(f); #print(input)

# LOAD KEYS INTO API
consumer_key=input["consumer_key"]    
consumer_secret=input["consumer_secret"]    
access_token=input["access_token"]    
access_token_secret=input["access_token_secret"]    
bearer_token=input["bearer_token"]

# %% [markdown]
# The next step is creating an OAuthHandler instance by passing our consumer token and secret keys.

# %%
import tweepy
# Set up Connection
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# So now that we have our OAuthHandler equipped with an access token, we are ready for business:

# %% [markdown]
# ### Hello world example
#
# This example will download your home timeline tweets and print each one of their texts to the console.
#
# The Authentication Tutorial goes into more details about authentication.

# %%
import tweepy
print("tweepy version =",tweepy.__version__)

# Set up Connection
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

#print username
my_user_name=api.verify_credentials().screen_name
print("username=",my_user_name)

# Returns the 20 most recent statuses, including retweets, 
# posted by the authenticating user and that user’s friends. 
public_tweets = api.home_timeline()

# Print tweets to screen
for tweet in public_tweets:
    print(tweet.text)
# Out:
# tweepy version = 4.12.1
# username= elliotzlii
# How to survive the holiday season https://t.co/94sazD4coK  | opinion
# The humbling of Xi Jinping https://t.co/zTOYIKBd1k
# Some of China’s most severe lock­downs have been in border regions such as Xinjiang and Tibet, both of which have b… https://t.co/OkvU1lWIEo
# This year's Best in Travel list has been sorted by the trip "type" — eat, journey, connect, learn, unwind — to help… https://t.co/UZFmutp1aU
# President Joe Biden sought to boost Raphael Warnock’s campaign in Georgia, telling Democratic allies that Herschel… https://t.co/oLGZORZtpK
# The tree-killing disease that decimated Florida orange groves is intensifying across Brazil, the biggest juice prod… https://t.co/ihL3Qg7cT2
# Twitter's credit grade was withdrawn by S&amp;P because it lacks enough information to cover the platform https://t.co/mWGCGXAhFb
# French President Emmanuel Macron says he wants to resolve a dispute over industrial subsidies with the US “in the f… https://t.co/7czACD29hO
# A ring made with an emerald that was lost on a Spanish shipwreck for four centuries will come to auction for the fi… https://t.co/JxqN4jjF1m
# France’s credit outlook was downgraded to negative by S&amp;P Global as the nation’s slowing economy and the measures t… https://t.co/DPOcAFtWmL
# Stock traders are dialing up their risk appetites at the tail-end of a brutal year https://t.co/5OuEfZxuGR
# Home-insurance premiums are rising. Here’s how to trim your bill. https://t.co/Gt2kXE9efb
# Founder Of Fast-Fashion Phenomenon Shein Joins Ranks Of China’s Richest After New Fundraising… https://t.co/qIAbJWRLdQ
# Anticipating a Russian Attack, the Ukrainian Army Trained Its Tank Crews To Fight Like Artillery… https://t.co/AaC2tMVe0a
# Democrats vote to unseat Iowa as first contest in presidential primaries https://t.co/x7hiT1EeYY
# Democrats vote to unseat Iowa as first contest in presidential primaries https://t.co/mWN4lq0Z0B
# He Left MIT At 22 To Solve A Problem Investors Didn’t Get. Now His Company Is Worth $6 Billion… https://t.co/PXowq4r3cS
# #Qatar2022 is reportedly the most expensive sporting competition ever. However, the $200 billion #FIFAWorldCup may… https://t.co/CTNpQ8k4m3
# They were about chefs, comedians and washed-up spies
#  https://t.co/8BGxYS29IN
# US health officials are preparing to the end the emergency declaration for mpox https://t.co/i75CgcTbQf

# %% [markdown]
# **API**
#
# The API class (tweepy.API) provides access to the entire twitter RESTful API methods.
#
# Each method can accept various parameters and return responses.
#
# For more information about these methods please refer to the following
# https://docs.tweepy.org/en/stable/api.html#api-reference
#
# **Models**
#
# When we invoke an API method most of the time it will return a Tweepy model class instance.
#
# This will contain the data returned from Twitter which we can then use inside our application.
#
# For example the following code returns to us an User model:

# %% [markdown]
# ### Twitter search
#
# Returns a collection of relevant Tweets matching a specified query.
#
# **Option-1**

# %%
import requests 

# Set up Connection
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Define search twitter function
def search_twitter(query, tweet_fields, bearer_token = bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}

    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}".format(query, tweet_fields)
    
    print("--------------",url,"--------------")
    response = requests.request("GET", url, headers=headers)
    #print(response.status_code)
    # print(response.text)

    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

json_response = search_twitter(query="mental health", tweet_fields="tweet.fields=text,author_id,created_at", bearer_token=bearer_token)

print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# -------------- https://api.twitter.com/2/tweets/search/recent?query=mental health&tweet.fields=text,author_id,created_at --------------
# {
#     "data": [
#         {
#             "author_id": "764466229360766979",
#             "created_at": "2022-12-02T22:59:47.000Z",
#             "edit_history_tweet_ids": [
#                 "1598814214168383488"
#             ],
#             "id": "1598814214168383488",
#             "text": "RT @sarahswonderr: I think some of y\u2019all need to see it from Shawn\u2019s POV. He\u2019s always been in the spotlight, and deserves a break. He has t\u2026"
#         },
#         {
#             "author_id": "2747525205",
#             "created_at": "2022-12-02T22:59:47.000Z",
#             "edit_history_tweet_ids": [
#                 "1598814213065121792"
#             ],
#             "id": "1598814213065121792",
#             "text": "RT @RisenRabbit: one of the weirdest sets of beliefs you get on here is people being really pro-mental health awareness but also believing\u2026"
#         },
#         {
#             "author_id": "1082902741389922304",
#             "created_at": "2022-12-02T22:59:47.000Z",
#             "edit_history_tweet_ids": [
#                 "1598814210821062656"
#             ],
#             "id": "1598814210821062656",
#             "text": "RT @AusBassie: And when you pray tonight..pray for mental health. Don\u2019t just do it for you but for those around you too. This is the most d\u2026"
#         },
#         {
#             "author_id": "18279623",
#             "created_at": "2022-12-02T22:59:45.000Z",
#             "edit_history_tweet_ids": [
#                 "1598814206278893568"
#             ],
#             "id": "1598814206278893568",
#             "text": "RT @RichardvReeves: Given that specific demographic groups by race/gender are highlighted here by President Biden in his Mental Health Stra\u2026"
#         },
#         {
#             "author_id": "1337865024023359490",
#             "created_at": "2022-12-02T22:59:44.000Z",
#             "edit_history_tweet_ids": [
#                 "1598814199509286915"
#             ],
#             "id": "1598814199509286915",
#             "text": "\"Having a public breakdown\" == We're seeing the mental health state of a public figure that everyone in their inner circle had witnessed for years, but they fired their publicist, stopped listening to them, or pissed them off."
#         },
#         {
#             "author_id": "149637223",
#             "created_at": "2022-12-02T22:59:43.000Z",
#             "edit_history_tweet_ids": [
#                 "1598814194807103488"
#             ],
#             "id": "1598814194807103488",
#             "text": "1. Mental Health is such a taboo thing in our society. As a teen I considered it once. I was 17. My hero\u2019s where Trent Reznor, David Bowie, Al Jourganson or Ministry, Brian Malko of Placebo. They all bent the lines between man and women. I came home with a woman\u2019s shirt on,"
#         },
#         {
#             "author_id": "1561685341685575682",
#             "created_at": "2022-12-02T22:59:41.000Z",
#             "edit_history_tweet_ids": [
#                 "1598814188125945862"
#             ],
#             "id": "1598814188125945862",
#             "text": "RT @AusBassie: And when you pray tonight..pray for mental health. Don\u2019t just do it for you but for those around you too. This is the most d\u2026"
#         },
#         {
#             "author_id": "709732147272224768",
#             "created_at": "2022-12-02T22:59:39.000Z",
#             "edit_history_tweet_ids": [
#                 "1598814180890460162"
#             ],
#             "id": "1598814180890460162",
#             "text": "smoked too much trying to help my mental health -&gt; developed a respiratory infection-&gt; mental health plummets because I\u2019m sick AND sober"
#         },
#         {
#             "author_id": "1496899919050948622",
#             "created_at": "2022-12-02T22:59:39.000Z",
#             "edit_history_tweet_ids": [
#                 "1598814180357951488"
#             ],
#             "id": "1598814180357951488",
#             "text": "@code2high @DrProudman He didn't submit a signed declaration that she didn't hurt him only that they were not gonna claim damages for the abuse she inflicted on him i.e the mental health impacts her abuse had, it's a big difference"
#         }
#     ],
#     "meta": {
#         "newest_id": "1598814214168383488",
#         "next_token": "b26v89c19zqg8o3fpzhmlch04gi0nb37trz3c40w03tkt",
#         "oldest_id": "1598814180357951488",
#         "result_count": 9
#     }
# }

# %% [markdown]
# **Option-2**
#
# Please note that Twitter’s search service and, by extension, the Search API is not meant to be an exhaustive source of Tweets.
#
# Not all Tweets will be indexed or made available via the search interface.
#
# Twitter’s standard search API only “searches against a sampling of recent Tweets published in the past 7 days.”
#
# https://docs.tweepy.org/en/stable/api.html#tweepy.API.search_tweets

# %%
# define pretty print function
def pretty_print_json(input):
    print(json.dumps(input, indent=4))

# %%
# Use api basic search to get 2 tweets given the query 
search_results = api.search_tweets("mental health", lang="en", count=5)
print(type(search_results))
print(search_results)

# %%
print("--------------First tweet meta JSON data-------------")
pretty_print_json(search_results[1]._json)

# %% [markdown]
# ### Search multiple tweets

# %%
number_of_tweets=100
search_results = api.search_tweets("mental health", lang="en", count=number_of_tweets)

for i in range(0,number_of_tweets):
    try:
        print("-------- tweet = ",i," -------")
        print("text = ",search_results[i]._json["text"])
        print("retweeted = ",search_results[i]._json["retweeted"])
        print("retweet_count = ",search_results[i]._json["retweet_count"])
        print("created_at =" ,search_results[i]._json["created_at"])
        print("id_str = ",search_results[i]._json["id_str"])
        print("url = https://twitter.com/i/web/status/"+search_results[i]._json["id_str"])

    except:
        print("ERROR")
# Out:
# -------- tweet =  0  -------
# text =  RT @THed2113: Are you stuck at 1 viewer and inactive chat? Join #KOOPATROOP for 24/7 support runs, mental health awareness and MASSIVE raid…
# retweeted =  False
# retweet_count =  1
# created_at = Fri Dec 02 23:00:03 +0000 2022
# id_str =  1598814281142865925
# url = https://twitter.com/i/web/status/1598814281142865925
# -------- tweet =  1  -------
# text =  @cjoblonskiwicz @MuellerSheWrote Not everyone with a mental health condition is a danger to themselves and others b… https://t.co/K5GUvccUHR
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 23:00:03 +0000 2022
# id_str =  1598814279851180036
# url = https://twitter.com/i/web/status/1598814279851180036
# -------- tweet =  2  -------
# text =  Denver sheriff Elias Diggins, an #MSUDenver graduate, has a reputation for empathy. He has also made mental health… https://t.co/PpPFFB1Qlh
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 23:00:01 +0000 2022
# id_str =  1598814271487455232
# url = https://twitter.com/i/web/status/1598814271487455232
# -------- tweet =  3  -------
# text =  RT @WealthInc247: Your mental health matters more than others' feelings.
# retweeted =  False
# retweet_count =  87
# created_at = Fri Dec 02 23:00:01 +0000 2022
# id_str =  1598814271265071104
# url = https://twitter.com/i/web/status/1598814271265071104
# -------- tweet =  4  -------
# text =  @skrunkIey @dinosaurs1969 Trust me, yes. you did. It kills your mental health. I have to be in tomorrow 7AM- 3PM...… https://t.co/B1M3YmKdYG
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 23:00:01 +0000 2022
# id_str =  1598814271156240385
# url = https://twitter.com/i/web/status/1598814271156240385
# -------- tweet =  5  -------
# text =  ICYMI:  #IAVA hosted a very informative Facebook Live discussion with @myriadgenetics!
# LEARN how pharmacogenomic te… https://t.co/P5gNznJkMp
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 23:00:01 +0000 2022
# id_str =  1598814270816296961
# url = https://twitter.com/i/web/status/1598814270816296961
# -------- tweet =  6  -------
# text =  Frontline managers generally take care of incidents as they happen — but they don’t pay as much attention to the lo… https://t.co/XdBYkIiCJO
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 23:00:00 +0000 2022
# id_str =  1598814268022996992
# url = https://twitter.com/i/web/status/1598814268022996992
# -------- tweet =  7  -------
# text =  Are you stuck at 1 viewer and inactive chat? Join #KOOPATROOP for 24/7 support runs, mental health awareness and MA… https://t.co/TeLlbU98HH
# retweeted =  False
# retweet_count =  1
# created_at = Fri Dec 02 23:00:00 +0000 2022
# id_str =  1598814267200835584
# url = https://twitter.com/i/web/status/1598814267200835584
# -------- tweet =  8  -------
# text =  In my heart, I see a retired mental consultant that needs to check his mental health but for your information, I am… https://t.co/z6ke4gFNog
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:59 +0000 2022
# id_str =  1598814261400068096
# url = https://twitter.com/i/web/status/1598814261400068096
# -------- tweet =  9  -------
# text =  RT @RealStevefriend: #32. Have you offered mental health counseling to @FBIJacksonville SAC Sherry Onks for the anxiety she reported feelin…
# retweeted =  False
# retweet_count =  35
# created_at = Fri Dec 02 22:59:54 +0000 2022
# id_str =  1598814240768335872
# url = https://twitter.com/i/web/status/1598814240768335872
# -------- tweet =  10  -------
# text =  @Zeroxmachina @BigBalls8686 @wildtiktokss Im not entertaining the obvious mental health issues you have.
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:53 +0000 2022
# id_str =  1598814238163640321
# url = https://twitter.com/i/web/status/1598814238163640321
# -------- tweet =  11  -------
# text =  RT @AusBassie: And when you pray tonight..pray for mental health. Don’t just do it for you but for those around you too. This is the most d…
# retweeted =  False
# retweet_count =  3239
# created_at = Fri Dec 02 22:59:52 +0000 2022
# id_str =  1598814232354627584
# url = https://twitter.com/i/web/status/1598814232354627584
# -------- tweet =  12  -------
# text =  RT @dude_gang: mental health awareness? Don’t need it. I’m fully aware I’m mentally ill.
# retweeted =  False
# retweet_count =  5
# created_at = Fri Dec 02 22:59:51 +0000 2022
# id_str =  1598814229628583940
# url = https://twitter.com/i/web/status/1598814229628583940
# -------- tweet =  13  -------
# text =  RT @chelseahartisme: As someone who struggled with mental illness to the point of attempting to take my own life, it is triggering AF to se…
# retweeted =  False
# retweet_count =  79
# created_at = Fri Dec 02 22:59:50 +0000 2022
# id_str =  1598814227376242689
# url = https://twitter.com/i/web/status/1598814227376242689
# -------- tweet =  14  -------
# text =  RT @middleageriot: PHOTO: When nobody wasted time speculating on the mental health of Nazis. https://t.co/19iV5R9cqR
# retweeted =  False
# retweet_count =  232
# created_at = Fri Dec 02 22:59:50 +0000 2022
# id_str =  1598814225098416128
# url = https://twitter.com/i/web/status/1598814225098416128
# -------- tweet =  15  -------
# text =  @OldParaTRP @MSNBC @SecDef The moment I started seeing a mental health provider, my chain of command treated me lik… https://t.co/GBGFmBEuqf
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:50 +0000 2022
# id_str =  1598814224209387522
# url = https://twitter.com/i/web/status/1598814224209387522
# -------- tweet =  16  -------
# text =  RT @sarahswonderr: I think some of y’all need to see it from Shawn’s POV. He’s always been in the spotlight, and deserves a break. He has t…
# retweeted =  False
# retweet_count =  21
# created_at = Fri Dec 02 22:59:47 +0000 2022
# id_str =  1598814214168383488
# url = https://twitter.com/i/web/status/1598814214168383488
# -------- tweet =  17  -------
# text =  RT @RisenRabbit: one of the weirdest sets of beliefs you get on here is people being really pro-mental health awareness but also believing…
# retweeted =  False
# retweet_count =  4020
# created_at = Fri Dec 02 22:59:47 +0000 2022
# id_str =  1598814213065121792
# url = https://twitter.com/i/web/status/1598814213065121792
# -------- tweet =  18  -------
# text =  RT @AusBassie: And when you pray tonight..pray for mental health. Don’t just do it for you but for those around you too. This is the most d…
# retweeted =  False
# retweet_count =  3239
# created_at = Fri Dec 02 22:59:47 +0000 2022
# id_str =  1598814210821062656
# url = https://twitter.com/i/web/status/1598814210821062656
# -------- tweet =  19  -------
# text =  RT @RichardvReeves: Given that specific demographic groups by race/gender are highlighted here by President Biden in his Mental Health Stra…
# retweeted =  False
# retweet_count =  6
# created_at = Fri Dec 02 22:59:45 +0000 2022
# id_str =  1598814206278893568
# url = https://twitter.com/i/web/status/1598814206278893568
# -------- tweet =  20  -------
# text =  "Having a public breakdown" == We're seeing the mental health state of a public figure that everyone in their inner… https://t.co/ETA4kYGDND
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:44 +0000 2022
# id_str =  1598814199509286915
# url = https://twitter.com/i/web/status/1598814199509286915
# -------- tweet =  21  -------
# text =  1. Mental Health is such a taboo thing in our society. As a teen I considered it once. I was 17. My hero’s where Tr… https://t.co/4RmWOq0V0y
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:43 +0000 2022
# id_str =  1598814194807103488
# url = https://twitter.com/i/web/status/1598814194807103488
# -------- tweet =  22  -------
# text =  RT @AusBassie: And when you pray tonight..pray for mental health. Don’t just do it for you but for those around you too. This is the most d…
# retweeted =  False
# retweet_count =  3239
# created_at = Fri Dec 02 22:59:41 +0000 2022
# id_str =  1598814188125945862
# url = https://twitter.com/i/web/status/1598814188125945862
# -------- tweet =  23  -------
# text =  smoked too much trying to help my mental health -&gt; developed a respiratory infection-&gt; mental health plummets because I’m sick AND sober
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:39 +0000 2022
# id_str =  1598814180890460162
# url = https://twitter.com/i/web/status/1598814180890460162
# -------- tweet =  24  -------
# text =  @code2high @DrProudman He didn't submit a signed declaration that she didn't hurt him only that they were not gonna… https://t.co/dUCWzsNcLH
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:39 +0000 2022
# id_str =  1598814180357951488
# url = https://twitter.com/i/web/status/1598814180357951488
# -------- tweet =  25  -------
# text =  @TheoFleury14 I seriously think you need mental health help, way too much anger and obsession going on.
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:37 +0000 2022
# id_str =  1598814170467602433
# url = https://twitter.com/i/web/status/1598814170467602433
# -------- tweet =  26  -------
# text =  Black Women Affirmations and Emotional Self-Care: 2 Powerful Books in 1: Boost Your Confidence &amp; Mental Health in 9… https://t.co/0e1u63TaJn
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:36 +0000 2022
# id_str =  1598814165774131200
# url = https://twitter.com/i/web/status/1598814165774131200
# -------- tweet =  27  -------
# text =  RT @drachenovska: @BuzzFeedNews Privacy is a narrative created by the British Press and they've never bothered to check each other. Racism,…
# retweeted =  False
# retweet_count =  14
# created_at = Fri Dec 02 22:59:36 +0000 2022
# id_str =  1598814164998553602
# url = https://twitter.com/i/web/status/1598814164998553602
# -------- tweet =  28  -------
# text =  RT @talkSPORT: “I was very low, I was very down. I was getting back to 2016 days.”
#
# @Tyson_Fury discusses his mental health struggles befor…
# retweeted =  False
# retweet_count =  5
# created_at = Fri Dec 02 22:59:34 +0000 2022
# id_str =  1598814158568333313
# url = https://twitter.com/i/web/status/1598814158568333313
# -------- tweet =  29  -------
# text =  RT @AusBassie: And when you pray tonight..pray for mental health. Don’t just do it for you but for those around you too. This is the most d…
# retweeted =  False
# retweet_count =  3239
# created_at = Fri Dec 02 22:59:33 +0000 2022
# id_str =  1598814155557011459
# url = https://twitter.com/i/web/status/1598814155557011459
# -------- tweet =  30  -------
# text =  RT @PPR_Org: This #NewScript crew know how to have the craic!
#
# This year our mental health movement has welcomed lots of new faces.
#
# We lo…
# retweeted =  False
# retweet_count =  3
# created_at = Fri Dec 02 22:59:29 +0000 2022
# id_str =  1598814138091945988
# url = https://twitter.com/i/web/status/1598814138091945988
# -------- tweet =  31  -------
# text =  @MGKSDIABLO Well I get that he has mental health issues but it's clear he's being used and at least, maybe someone should say something.
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:29 +0000 2022
# id_str =  1598814137588531201
# url = https://twitter.com/i/web/status/1598814137588531201
# -------- tweet =  32  -------
# text =  How did I recognise my mental health was slipping? I didn't. Dr Carrie-Anne M NT #doctorshealth
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:29 +0000 2022
# id_str =  1598814136498257924
# url = https://twitter.com/i/web/status/1598814136498257924
# -------- tweet =  33  -------
# text =  RT @nya4short: No one takes black woman serious.
# From domestic violence, sexual assault or sexual harassment, toxic relationships and daddy…
# retweeted =  False
# retweet_count =  1
# created_at = Fri Dec 02 22:59:29 +0000 2022
# id_str =  1598814135138992128
# url = https://twitter.com/i/web/status/1598814135138992128
# -------- tweet =  34  -------
# text =  RT @introvertsmemes: normalize avoiding people who are not good for your mental health
# retweeted =  False
# retweet_count =  9485
# created_at = Fri Dec 02 22:59:28 +0000 2022
# id_str =  1598814132110651393
# url = https://twitter.com/i/web/status/1598814132110651393
# -------- tweet =  35  -------
# text =  RT @middleageriot: PHOTO: When nobody wasted time speculating on the mental health of Nazis. https://t.co/19iV5R9cqR
# retweeted =  False
# retweet_count =  232
# created_at = Fri Dec 02 22:59:24 +0000 2022
# id_str =  1598814114293456898
# url = https://twitter.com/i/web/status/1598814114293456898
# -------- tweet =  36  -------
# text =  Because the ACLU defended Skokie Nazis having a parade, it is horrible censorship to prevent the person in the mids… https://t.co/U6zZavjFp5
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:22 +0000 2022
# id_str =  1598814106378596352
# url = https://twitter.com/i/web/status/1598814106378596352
# -------- tweet =  37  -------
# text =  @NfiniteRedghost Well, it wouldn’t be advantageous to me to prove a false truth wrong if it’s a lie. If you’re livi… https://t.co/s7rsuaeIaF
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:22 +0000 2022
# id_str =  1598814106299076609
# url = https://twitter.com/i/web/status/1598814106299076609
# -------- tweet =  38  -------
# text =  @Robshuk121 @JamesTravis1964 @w_terrence Do you think all Nazis/sympathizers have a mental health condition?
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:21 +0000 2022
# id_str =  1598814105087139840
# url = https://twitter.com/i/web/status/1598814105087139840
# -------- tweet =  39  -------
# text =  RT @YoloAkili: The problem with so many of our analyses on mental health is so many have no critique of the DSM and the history of psychiat…
# retweeted =  False
# retweet_count =  123
# created_at = Fri Dec 02 22:59:21 +0000 2022
# id_str =  1598814103576973315
# url = https://twitter.com/i/web/status/1598814103576973315
# -------- tweet =  40  -------
# text =  R$E:
# A message of hope for those suffering with mental health difficulties...
# (12 mins)
#
# https://t.co/WJQRGyPNHq
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:21 +0000 2022
# id_str =  1598814101949468672
# url = https://twitter.com/i/web/status/1598814101949468672
# -------- tweet =  41  -------
# text =  We’d rather they spread disease and play Russian Roulette with their health!! No need to invest in mental health se… https://t.co/x0rMKLe9nF
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:16 +0000 2022
# id_str =  1598814083494486016
# url = https://twitter.com/i/web/status/1598814083494486016
# -------- tweet =  42  -------
# text =  RT @AusBassie: And when you pray tonight..pray for mental health. Don’t just do it for you but for those around you too. This is the most d…
# retweeted =  False
# retweet_count =  3239
# created_at = Fri Dec 02 22:59:14 +0000 2022
# id_str =  1598814076028997633
# url = https://twitter.com/i/web/status/1598814076028997633
# -------- tweet =  43  -------
# text =  RT @philmupp1: @ElaineM11584892 A govt more concerned with the health / mental health issues of their minister Linda Reynolds and who treat…
# retweeted =  False
# retweet_count =  6
# created_at = Fri Dec 02 22:59:14 +0000 2022
# id_str =  1598814074103791617
# url = https://twitter.com/i/web/status/1598814074103791617
# -------- tweet =  44  -------
# text =  @trusoslay I forgot about this 💀 our mental health always at risk with russian skaters https://t.co/hnGrlWXHoN
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:08 +0000 2022
# id_str =  1598814049982189574
# url = https://twitter.com/i/web/status/1598814049982189574
# -------- tweet =  45  -------
# text =  RT @GvcciHoochie: Hey everyone I’m fundraising bc I found out short notice I have til the end of jan to find housing. I’m currently dealing…
# retweeted =  False
# retweet_count =  28
# created_at = Fri Dec 02 22:59:08 +0000 2022
# id_str =  1598814047083802624
# url = https://twitter.com/i/web/status/1598814047083802624
# -------- tweet =  46  -------
# text =  @mfreckelton99 Plus he’s had innumerable opportunities to get help he refuses to get it.  He’s also an adult who sh… https://t.co/aqMIOBsktK
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:06 +0000 2022
# id_str =  1598814042457485312
# url = https://twitter.com/i/web/status/1598814042457485312
# -------- tweet =  47  -------
# text =  RT @YoloAkili: The problem with so many of our analyses on mental health is so many have no critique of the DSM and the history of psychiat…
# retweeted =  False
# retweet_count =  123
# created_at = Fri Dec 02 22:59:04 +0000 2022
# id_str =  1598814031833333761
# url = https://twitter.com/i/web/status/1598814031833333761
# -------- tweet =  48  -------
# text =  @The_Dogs_Bolox @JosephMcNutt13 @AndreaMurray67 @IrishTimes So being taught about transgenders takes an entire scho… https://t.co/8r7WB2GvRm
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:59:00 +0000 2022
# id_str =  1598814016457277443
# url = https://twitter.com/i/web/status/1598814016457277443
# -------- tweet =  49  -------
# text =  I would never vote for Walker but, it's despicable what the GOP is doing.  Users.   The GOP knew his history.   The… https://t.co/lfsY1iYX3Y
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:57 +0000 2022
# id_str =  1598814002464923652
# url = https://twitter.com/i/web/status/1598814002464923652
# -------- tweet =  50  -------
# text =  @peters_malcolm Because it has no chance of a conviction, and to save face the prosecution are playing the, ‘mental health’, card.
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:56 +0000 2022
# id_str =  1598813998279163904
# url = https://twitter.com/i/web/status/1598813998279163904
# -------- tweet =  51  -------
# text =  RT @sadedposts: my mental health is getting bad again.
# retweeted =  False
# retweet_count =  5824
# created_at = Fri Dec 02 22:58:56 +0000 2022
# id_str =  1598813997889093635
# url = https://twitter.com/i/web/status/1598813997889093635
# -------- tweet =  52  -------
# text =  I'm glad my mum supports me and supports my mental too and is helping me get help from mental health professionals… https://t.co/TPIw8i8OGf
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:56 +0000 2022
# id_str =  1598813997398204416
# url = https://twitter.com/i/web/status/1598813997398204416
# -------- tweet =  53  -------
# text =  Brain Energy: A Revolutionary Breakthrough in Understanding Mental Health--and Improving Treatment for Anxiety, Dep… https://t.co/p3mCTSMB6n
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:56 +0000 2022
# id_str =  1598813997394165761
# url = https://twitter.com/i/web/status/1598813997394165761
# -------- tweet =  54  -------
# text =  RT @AmateurFA: The next in our series of Mental Health Aware workshops with @orangeballcoach will take place in December.
#
# Learn how you c…
# retweeted =  False
# retweet_count =  2
# created_at = Fri Dec 02 22:58:55 +0000 2022
# id_str =  1598813995523194880
# url = https://twitter.com/i/web/status/1598813995523194880
# -------- tweet =  55  -------
# text =  RT @Tranimus85: @WhatTheTrans I was at the funeral of a trans person who completed suicide the other day.
#
# They were misgendered throughout…
# retweeted =  False
# retweet_count =  4
# created_at = Fri Dec 02 22:58:54 +0000 2022
# id_str =  1598813990347591681
# url = https://twitter.com/i/web/status/1598813990347591681
# -------- tweet =  56  -------
# text =  RT @AusBassie: And when you pray tonight..pray for mental health. Don’t just do it for you but for those around you too. This is the most d…
# retweeted =  False
# retweet_count =  3239
# created_at = Fri Dec 02 22:58:53 +0000 2022
# id_str =  1598813988007120899
# url = https://twitter.com/i/web/status/1598813988007120899
# -------- tweet =  57  -------
# text =  RT @AusBassie: And when you pray tonight..pray for mental health. Don’t just do it for you but for those around you too. This is the most d…
# retweeted =  False
# retweet_count =  3239
# created_at = Fri Dec 02 22:58:53 +0000 2022
# id_str =  1598813985591132163
# url = https://twitter.com/i/web/status/1598813985591132163
# -------- tweet =  58  -------
# text =  Chemical Khichdi: How I Hack My Mental Health IHSZUGE
#
# https://t.co/ccE3qQHlo2 https://t.co/E59FPsX0I4
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:52 +0000 2022
# id_str =  1598813983620071424
# url = https://twitter.com/i/web/status/1598813983620071424
# -------- tweet =  59  -------
# text =  RT @GoldingGirl617: Britney Spears was under a conservatorship for 13 years because of her mental health.
#
# She's never said anything racis…
# retweeted =  False
# retweet_count =  315
# created_at = Fri Dec 02 22:58:52 +0000 2022
# id_str =  1598813980528476160
# url = https://twitter.com/i/web/status/1598813980528476160
# -------- tweet =  60  -------
# text =  RT @theskycriestoo: I hate the term 'It's all in your head' when people use it for mental health issues cuz, news flash, your brain is an o…
# retweeted =  False
# retweet_count =  2
# created_at = Fri Dec 02 22:58:50 +0000 2022
# id_str =  1598813972530049024
# url = https://twitter.com/i/web/status/1598813972530049024
# -------- tweet =  61  -------
# text =  We were able to see and hear the wonderful stories of woman seed savers, growers, and producers from CCR… https://t.co/uWXsVKeFtM
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:48 +0000 2022
# id_str =  1598813966414843907
# url = https://twitter.com/i/web/status/1598813966414843907
# -------- tweet =  62  -------
# text =  RT @sleepisocialist: I think most Americans underestimate just how much better their life would be if they could get around easily without…
# retweeted =  False
# retweet_count =  7958
# created_at = Fri Dec 02 22:58:47 +0000 2022
# id_str =  1598813960509300737
# url = https://twitter.com/i/web/status/1598813960509300737
# -------- tweet =  63  -------
# text =  The Trans Guide to Mental Health and Well-Being TOBZODT
#
# https://t.co/ITMgGH5E8w https://t.co/pg425lle3d
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:45 +0000 2022
# id_str =  1598813953483997186
# url = https://twitter.com/i/web/status/1598813953483997186
# -------- tweet =  64  -------
# text =  RT @BelleStruts: The Ancient Republican philosopher Hypocritticus says one must vote against all bills that provide free lunches to poor ki…
# retweeted =  False
# retweet_count =  5
# created_at = Fri Dec 02 22:58:39 +0000 2022
# id_str =  1598813927730974720
# url = https://twitter.com/i/web/status/1598813927730974720
# -------- tweet =  65  -------
# text =  RT @dave43law: @BellaWallerstei Please advise the 3% that mental health services are available - but there is one heck of a waiting list be…
# retweeted =  False
# retweet_count =  3
# created_at = Fri Dec 02 22:58:39 +0000 2022
# id_str =  1598813927097307136
# url = https://twitter.com/i/web/status/1598813927097307136
# -------- tweet =  66  -------
# text =  RT @TehutiKhem: When your mental health is not in the best state, give yourself a break. Don’t feel guilty for things you can’t do. Normal…
# retweeted =  False
# retweet_count =  28
# created_at = Fri Dec 02 22:58:38 +0000 2022
# id_str =  1598813925243604994
# url = https://twitter.com/i/web/status/1598813925243604994
# -------- tweet =  67  -------
# text =  RT @turtlebreezee: Protect your mental health by not looking at things you know will trigger it
# retweeted =  False
# retweet_count =  31212
# created_at = Fri Dec 02 22:58:38 +0000 2022
# id_str =  1598813924266504192
# url = https://twitter.com/i/web/status/1598813924266504192
# -------- tweet =  68  -------
# text =  @notsleeeping @TheCovalentTV @nikkita_wwe Well that’s good for her mental health because being on Twitter and other… https://t.co/R8VRB73Ekx
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:38 +0000 2022
# id_str =  1598813923892944900
# url = https://twitter.com/i/web/status/1598813923892944900
# -------- tweet =  69  -------
# text =  RT @samdylanfinch: Unexpected worsening mental health. Transition is incredibly difficult, and it’s not always the mental health bandaid th…
# retweeted =  False
# retweet_count =  9
# created_at = Fri Dec 02 22:58:37 +0000 2022
# id_str =  1598813917467361283
# url = https://twitter.com/i/web/status/1598813917467361283
# -------- tweet =  70  -------
# text =  RT @sadtruthwords: I'm sorry for all the times my mental health made me a bad friend.
# retweeted =  False
# retweet_count =  55
# created_at = Fri Dec 02 22:58:36 +0000 2022
# id_str =  1598813913600122881
# url = https://twitter.com/i/web/status/1598813913600122881
# -------- tweet =  71  -------
# text =  Bad mental health day. Channeled some of that energy into making a wreath. https://t.co/XJXqp3IRbl
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:33 +0000 2022
# id_str =  1598813903537872896
# url = https://twitter.com/i/web/status/1598813903537872896
# -------- tweet =  72  -------
# text =  @MichaelBalmer19 @Ergun_Kazali @SnookerLoopy_ That statement is exactly why people suffer with mental health issues.
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:32 +0000 2022
# id_str =  1598813899050156034
# url = https://twitter.com/i/web/status/1598813899050156034
# -------- tweet =  73  -------
# text =  @NotHermitDruid What gets lost in this is that so many are willing to just accept the excuse of "Oh he's just *inse… https://t.co/SCtQaO7aj7
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:24 +0000 2022
# id_str =  1598813864975794176
# url = https://twitter.com/i/web/status/1598813864975794176
# -------- tweet =  74  -------
# text =  RT @jinnieslamp: “If you know how to deal with your mental health, it’s fine to keep it to yourself, but if you don’t, I think it’s good yo…
# retweeted =  False
# retweet_count =  458
# created_at = Fri Dec 02 22:58:21 +0000 2022
# id_str =  1598813853600841733
# url = https://twitter.com/i/web/status/1598813853600841733
# -------- tweet =  75  -------
# text =  now that I have basically every weekend and holiday off my mental health is significantly better 😌
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:19 +0000 2022
# id_str =  1598813842988990464
# url = https://twitter.com/i/web/status/1598813842988990464
# -------- tweet =  76  -------
# text =  I love being pampered. Going to the spa once a week is so therapeutical and amazing for my mental health 💆🏽‍♀️
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:19 +0000 2022
# id_str =  1598813842527903744
# url = https://twitter.com/i/web/status/1598813842527903744
# -------- tweet =  77  -------
# text =  RT @MindTendencies2: The real flex is pausing before reacting, observing without evaluating, interacting without absorbing, and calmly cont…
# retweeted =  False
# retweet_count =  7997
# created_at = Fri Dec 02 22:58:17 +0000 2022
# id_str =  1598813836316114946
# url = https://twitter.com/i/web/status/1598813836316114946
# -------- tweet =  78  -------
# text =  The fact that i was in therapy before people started taking mental health seriously is…..crazy!
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:16 +0000 2022
# id_str =  1598813831853068288
# url = https://twitter.com/i/web/status/1598813831853068288
# -------- tweet =  79  -------
# text =  @Nekochan211 Mental health and life situations are always a valid excuse imho, hope your groove finds you again 🙏
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:16 +0000 2022
# id_str =  1598813831563972608
# url = https://twitter.com/i/web/status/1598813831563972608
# -------- tweet =  80  -------
# text =  Why is college so stressful? College students are attempting to perform to their best ability academically and soci… https://t.co/fk9vpxCD8x
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:15 +0000 2022
# id_str =  1598813825880322048
# url = https://twitter.com/i/web/status/1598813825880322048
# -------- tweet =  81  -------
# text =  RT @RichardvReeves: Given that specific demographic groups by race/gender are highlighted here by President Biden in his Mental Health Stra…
# retweeted =  False
# retweet_count =  6
# created_at = Fri Dec 02 22:58:11 +0000 2022
# id_str =  1598813809786888192
# url = https://twitter.com/i/web/status/1598813809786888192
# -------- tweet =  82  -------
# text =  To anyone out there dealing with hardship, abuse, tragedy, mental health, pain, etc.
# You are not alone! Here for yo… https://t.co/jUOXaB82B0
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:10 +0000 2022
# id_str =  1598813806481887235
# url = https://twitter.com/i/web/status/1598813806481887235
# -------- tweet =  83  -------
# text =  RT @WSJ: President Biden met with Prince William in Boston to discuss efforts to address climate change and mental health, according to the…
# retweeted =  False
# retweet_count =  38
# created_at = Fri Dec 02 22:58:09 +0000 2022
# id_str =  1598813803705032704
# url = https://twitter.com/i/web/status/1598813803705032704
# -------- tweet =  84  -------
# text =  @AlexDGlengarry A cynical person may think that they realised that they didn't have a case and used the 'mental health' card.
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:58:07 +0000 2022
# id_str =  1598813793811066881
# url = https://twitter.com/i/web/status/1598813793811066881
# -------- tweet =  85  -------
# text =  RT @AusBassie: And when you pray tonight..pray for mental health. Don’t just do it for you but for those around you too. This is the most d…
# retweeted =  False
# retweet_count =  3239
# created_at = Fri Dec 02 22:58:06 +0000 2022
# id_str =  1598813788966297600
# url = https://twitter.com/i/web/status/1598813788966297600
# -------- tweet =  86  -------
# text =  RT @RealStevefriend: #32. Have you offered mental health counseling to @FBIJacksonville SAC Sherry Onks for the anxiety she reported feelin…
# retweeted =  False
# retweet_count =  35
# created_at = Fri Dec 02 22:58:01 +0000 2022
# id_str =  1598813768779444224
# url = https://twitter.com/i/web/status/1598813768779444224
# -------- tweet =  87  -------
# text =  @Robshuk121 @JamesTravis1964 @w_terrence Quit associating antisemitism with mental illness the way y'all do with ma… https://t.co/djHKdcbeoo
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:57:59 +0000 2022
# id_str =  1598813758486609921
# url = https://twitter.com/i/web/status/1598813758486609921
# -------- tweet =  88  -------
# text =  @OZSIMMO You just stay right there. Have some food delivered and take a mental health day.
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:57:58 +0000 2022
# id_str =  1598813756725002243
# url = https://twitter.com/i/web/status/1598813756725002243
# -------- tweet =  89  -------
# text =  RT @lindyli: Glenn Youngkin blames Chesapeake on mental health
#
# Greg Abbott blames Uvalde massacre on mental health
#
# Same guy who cut $211…
# retweeted =  False
# retweet_count =  2891
# created_at = Fri Dec 02 22:57:57 +0000 2022
# id_str =  1598813751733428225
# url = https://twitter.com/i/web/status/1598813751733428225
# -------- tweet =  90  -------
# text =  RT @PublicPriestley: What we are setting up here is grinding, rigid, intergenerational poverty and poor mental health that is inescapable b…
# retweeted =  False
# retweet_count =  20
# created_at = Fri Dec 02 22:57:56 +0000 2022
# id_str =  1598813747933581317
# url = https://twitter.com/i/web/status/1598813747933581317
# -------- tweet =  91  -------
# text =  @OccupyDemocrats You need to seek mental health.
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:57:55 +0000 2022
# id_str =  1598813743609413640
# url = https://twitter.com/i/web/status/1598813743609413640
# -------- tweet =  92  -------
# text =  @iHeartLeeKnow You should think about ppls mental health and well-being before doing this. A lot of you say ARMYs a… https://t.co/9Eq30uxGOq
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:57:55 +0000 2022
# id_str =  1598813741944311808
# url = https://twitter.com/i/web/status/1598813741944311808
# -------- tweet =  93  -------
# text =  RT @doodlelyfe_1: Ryuji drawing for my mental health
# -
# #persona5 #ryujisakamoto #persona5fanart #phantomthieves https://t.co/nD3bZa7k1Z
# retweeted =  False
# retweet_count =  162
# created_at = Fri Dec 02 22:57:52 +0000 2022
# id_str =  1598813731009470466
# url = https://twitter.com/i/web/status/1598813731009470466
# -------- tweet =  94  -------
# text =  @Slatzism Didn't that get debunked years ago? Same as the "mental health services always get overwhelmed on a full… https://t.co/oK17mf90ir
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:57:52 +0000 2022
# id_str =  1598813730040578049
# url = https://twitter.com/i/web/status/1598813730040578049
# -------- tweet =  95  -------
# text =  RT @DrAlecGrant: We’ve got the contract for: Grant and Carson (Eds) Autoethnographies in Psychology and Mental Health: New Voices. Routledg…
# retweeted =  False
# retweet_count =  2
# created_at = Fri Dec 02 22:57:51 +0000 2022
# id_str =  1598813725716369409
# url = https://twitter.com/i/web/status/1598813725716369409
# -------- tweet =  96  -------
# text =  @pualaleapanaewa This film was so beautiful and the themes of mental health, abandonment, reconnection and so much… https://t.co/q6I49VUMhf
# retweeted =  False
# retweet_count =  0
# created_at = Fri Dec 02 22:57:48 +0000 2022
# id_str =  1598813713229815808
# url = https://twitter.com/i/web/status/1598813713229815808
# -------- tweet =  97  -------
# text =  RT @AusBassie: And when you pray tonight..pray for mental health. Don’t just do it for you but for those around you too. This is the most d…
# retweeted =  False
# retweet_count =  3239
# created_at = Fri Dec 02 22:57:46 +0000 2022
# id_str =  1598813706296647680
# url = https://twitter.com/i/web/status/1598813706296647680
# -------- tweet =  98  -------
# text =  RT @blakandblack: What we learn from the abandonment of Bruce Lehrmann rape trial:
#
# Yet again a politically connected white male gets just-…
# retweeted =  False
# retweet_count =  15
# created_at = Fri Dec 02 22:57:44 +0000 2022
# id_str =  1598813695278448640
# url = https://twitter.com/i/web/status/1598813695278448640
# -------- tweet =  99  -------
# text =  RT @soulonatraipse: One of the most touching interviews I’ve watched in recent times.
#
# Learning disability, mental health challenges - it t…
# retweeted =  False
# retweet_count =  1
# created_at = Fri Dec 02 22:57:42 +0000 2022
# id_str =  1598813690299666432
# url = https://twitter.com/i/web/status/1598813690299666432

# %% [markdown]
# ### Cursor Tutorial
#
# Source: https://docs.tweepy.org/en/v3.5.0/cursor_tutorial.html
#
# Pagination, also known as paging, is the process of dividing a document into discrete pages, either electronic pages or printed pages.
#
# We use pagination a lot in Twitter API development.
#
# Iterating through timelines, user lists, direct messages, etc.
#
# In order to perform pagination we must supply a page/cursor parameter with each of our requests.
#
# The problem here is this requires a lot of boiler plate code just to manage the pagination loop.
#
# To help make pagination easier and require less code Tweepy has the Cursor object.
#
# Cursor handles all the pagination work for us behind the scene so our code can now focus entirely on processing the results.

# %% [markdown]
# ### Collecting a large number of Tweets
#
# Use special options when initializing the API. These tell it to wait while the Twitter time-limit windows elapse
#
# `api = tweepy.API(auth, wait_on_rate_limit=True)`

# %%
# NOTE: THE REDUNDANT IMPORTS AND FUNCTION DEFINITIONS IS INTENTIONAL TO MAKE THE CODE CELLS SELF CONTAINED 
import json
from logging import raiseExceptions 
import tweepy
import time
from datetime import datetime
import time
import os

# PRINT TWEEPY VERSION
print("tweepy version =",tweepy.__version__)

#----------------------
# READ API KEY FILE
#----------------------
f = open("api-keys.json")
input=json.load(f); #print(input)

# LOAD KEYS INTO API
consumer_key=input["consumer_key"]    
consumer_secret=input["consumer_secret"]    
access_token=input["access_token"]    
access_token_secret=input["access_token_secret"]    
bearer_token=input["bearer_token"]    

#----------------------
# DEFINE USEFUL FUNCTIONS
#----------------------

# DEFINE PRETTY PRINT JSON FUNCTION
def pretty_print_json(input):
    print(json.dumps(input, indent=4))

# DEFINE FUNCTION TO SAVE TWEEPY SEARCH RESULTS
#   searches=array with various tweepy search objects
#   TODO: ADD "full and sparse" mode
#          full = save all tweet data (100 tweeks ~ 1 MB  --> 100,000 ~ 1 GB)
#          sparse = only save most important info
def save_search_tweets_results(searches,info_str="",output_name="tweet-search.json"):
    # if(str(type(input)) == "<class 'tweepy.models.SearchResults'>"):
    if(str(type(searches)) == "<class 'list'>"):
        #COMBINE ALL JSONS FOR VARIOUS TWEETS INTO ON BIG JSON CALL "out"
        out={}
        out["search_info"]=info_str

        #LOOP OVER SEARCHES
        tweet_ids=[]
        k=0 #counter
        for search in searches:
            #LOOP OVER TWEETS IN SEARCH
            for i in range(0,len(search)):
                out[str(k)]=search[i]._json
                tweet_id=search[i]._json["id_str"]
                #CHECK FOR REDUNDANT TWEETS
                if tweet_id in tweet_ids:
                    print("WARNING: REPEATED TWEETS IN SAVED FILE; ID = ",tweet_id)
                tweet_ids.append(search[i]._json["id_str"])

                k+=1
            #pretty_print_json(out)

        #DELETE FILE IF IT EXIST (START FRESH)
        if os.path.exists(output_name):
            os.remove(output_name)

        #WRITE FILE
        with open(output_name, 'w') as f:
            json.dump(out, f)
    else: 
        raise RuntimeError("ERROR: Incorrect datatype")

#----------------------
# SET UP CONNECTION
#----------------------
#   Use special options when initializing the API. These tell
#   it to wait while the Twitter time-limit windows elapse
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True) 

#----------------------
# RUN SEARCH 
#----------------------

#SEARCH PARAM
query="mental"

# NUMBER OF TWEETS TO SEARCH 
number_of_tweets=100
# number_of_tweets=18000*2 
# ideally use multiples of 100 for number_of_tweets
# should be able to collect 18000 tweets every 15 minutes
start_time = time.time()
max_loop_time_hrs=5

# THIS WILL KEEP DOING SEARCHES FURTHER AND FURTHER BACK IN TIME
# USING THE MAX_ID TO THE TIMELINE 
num_tweets_collected=0
searches=[]
k=0
#KEEP SEARCHING UNTIL DESIRED NUMBER OF TWEETS COLLECTED
while num_tweets_collected<number_of_tweets or (time.time()-start_time)/60./60>max_loop_time_hrs: 
    try: 
        #FIRST SEARCH
        if len(searches)==0:
            search_results = api.search_tweets(query, lang="en", count=100)
        #ADDITIONAL SEARCHES
        else:
            search_results = api.search_tweets(query, lang="en", count=100,max_id=max_id_next)

        #UPDATE PARAMETERS
        num_tweets_collected+=len(search_results)
        max_id_next=int(search_results[-1]._json["id_str"])-1

        #SAVE SEARCH RESULTS
        searches.append(search_results)

        #SAVE TEMPORARY CHECKPOINTS (DONT DO TOO OFTEN .. SLOWS CODE DOWN)
        if(k%10==0):
            print("SEARCH-"+str(k)+" COMPLETED;  TWEETS_COLLECTED=",num_tweets_collected,"; TIME (s) = ",time.time() - start_time)
        if(k%25==0):
            save_search_tweets_results(searches,output_name="tmp-snapshot.json")
            
        k+=1
    except:
        print("WARNING: twitter search failed")

    #SLEEP 5 SECONDS BEFORE NEXT REQUEST 
    if(number_of_tweets>18000):
        time.sleep(5)
    else:
        time.sleep(0.2)
        

# REPORT BASIC SEARCH INFO
print(num_tweets_collected,len(searches))
print("search time (s) =", (time.time() - start_time)) #/60.)

#TIMESTAMP SEARCH 
now = datetime.now()
dt_string = now.strftime("%Y-%m-%Y-H%H-M%M-S%S")

#----------------------
# SAVE RESULTS
#----------------------
info_str="query = "+query+"; number_of_tweets = "+str(number_of_tweets)+"; date = "+str(dt_string)
out_name=str(dt_string)+"-twitter-search.json"
save_search_tweets_results(searches,info_str=info_str,output_name=out_name)

#CLEAN-UP TEMP FILES
os.remove("tmp-snapshot.json")
# import glob
# list_to_delete=glob.glob("./*-tmp-snapshot.json")
# for file in list_to_delete:
#     os.remove(file)
# Out:
# tweepy version = 4.12.1
# SEARCH-0 COMPLETED;  TWEETS_COLLECTED= 100 ; TIME (s) =  0.5594151020050049
# 100 1
# search time (s) = 0.7864289283752441

# %% [markdown]
# ### Tweepy user objects
#
# The User object in Tweepy module contains the information about a user.
#
# Here are the list of attributes in the User object :
#
# For more see: https://www.geeksforgeeks.org/python-user-object-in-tweepy/

# %%
# returns a user object 
user_info=api.get_user(screen_name="POTUS")

# print info about user
print(json.dumps(user_info._json, indent=4, sort_keys=True))
# Out:
# {
#     "contributors_enabled": false,
#     "created_at": "Wed Jan 13 00:37:08 +0000 2021",
#     "default_profile": true,
#     "default_profile_image": false,
#     "description": "46th President of the United States, husband to @FLOTUS, proud dad & pop. Tweets may be archived: https://t.co/HDhBZBkKpU\nText me: (302) 404-0880",
#     "entities": {
#         "description": {
#             "urls": [
#                 {
#                     "display_url": "whitehouse.gov/privacy",
#                     "expanded_url": "http://whitehouse.gov/privacy",
#                     "indices": [
#                         98,
#                         121
#                     ],
#                     "url": "https://t.co/HDhBZBkKpU"
#                 }
#             ]
#         },
#         "url": {
#             "urls": [
#                 {
#                     "display_url": "WhiteHouse.gov",
#                     "expanded_url": "http://WhiteHouse.gov",
#                     "indices": [
#                         0,
#                         23
#                     ],
#                     "url": "https://t.co/MzB1JWfbJ0"
#                 }
#             ]
#         }
#     },
#     "favourites_count": 4,
#     "follow_request_sent": false,
#     "followers_count": 28056030,
#     "following": false,
#     "friends_count": 14,
#     "geo_enabled": false,
#     "has_extended_profile": true,
#     "id": 1349149096909668363,
#     "id_str": "1349149096909668363",
#     "is_translation_enabled": false,
#     "is_translator": false,
#     "lang": null,
#     "listed_count": 21545,
#     "location": "",
#     "name": "President Biden",
#     "notifications": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": null,
#     "profile_background_image_url_https": null,
#     "profile_background_tile": false,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1349149096909668363/1668467058",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1380530524779859970/TfwVAbyX_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1380530524779859970/TfwVAbyX_normal.jpg",
#     "profile_link_color": "1DA1F2",
#     "profile_location": null,
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "protected": false,
#     "screen_name": "POTUS",
#     "status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Dec 02 23:00:34 +0000 2022",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "expanded_url": "https://twitter.com/i/web/status/1598814410008576003",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "url": "https://t.co/6sKVQ0D7sI"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 0,
#         "favorited": false,
#         "geo": null,
#         "id": 1598814410008576003,
#         "id_str": "1598814410008576003",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 0,
#         "retweeted": false,
#         "source": "<a href=\"https://www.sprinklr.com\" rel=\"nofollow\">The White House</a>",
#         "text": "Our rail system is the backbone of our supply chain. Without it, industries would shut down and hundreds of thousan\u2026 https://t.co/6sKVQ0D7sI",
#         "truncated": true
#     },
#     "statuses_count": 4703,
#     "time_zone": null,
#     "translator_type": "none",
#     "url": "https://t.co/MzB1JWfbJ0",
#     "utc_offset": null,
#     "verified": true,
#     "withheld_in_countries": []
# }

# %% [markdown]
# ### XTRA CODE

# %%
# #CHECK IF REPEATED SEARCH WITH SAME QUERY RESULT IN SAME OUTPUT 

# def quick_print(search_results):
#     for i in range(0,number_of_tweets):
#         try:
#             print("-------- tweet = ",i," -------")
#             print("text = ",search_results[i]._json["text"])
#             print("url = https://twitter.com/i/web/status/"+search_results[i]._json["id_str"])
#         except:
#             print("ERROR")

# #SEARCH-1
# number_of_tweets=100
# search_results = api.search_tweets("texas OR maryland", lang="en", count=number_of_tweets)
# quick_print(search_results)

# #SEARCH-2
# number_of_tweets=100
# search_results = api.search_tweets("texas OR maryland", lang="en", count=number_of_tweets)
# quick_print(search_results)
