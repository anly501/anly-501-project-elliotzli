# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df1 = pd.read_csv('../../data/pre-clean data/Any Mental Illness in Past Year- Among People Aged 18 or Older; by Demographic Characteristics, Numbers in Thousands, 2008-2020.csv')
df2 = pd.read_csv('../../data/pre-clean data/Any Mental Illness in Past Year- Among People Aged 18 or Older; by Geographic and Socioeconomic Characteristics, Numbers in Thousands, 2008-2020.csv')

# %%
df1
# Out:
#    Demographic Characteristic   20081    2009    2010    2011    2012    2013  \
# 0                       TOTAL  39,826  41,195  41,417  41,381  43,714  43,846
# 1                   AGE GROUP     NaN     NaN     NaN     NaN     NaN     NaN
# 2                       18-25   6,099   6,043   6,151   6,356   6,774   6,754
# 3                 26 or Older  33,727  35,152  35,266  35,025  36,940  37,092
# 4                       26-49  20,697  21,455  20,648  19,936  20,777  21,061
# 5                 50 or Older  13,030  13,698  14,618  15,089  16,163  16,031
# 6                      GENDER     NaN     NaN     NaN     NaN     NaN     NaN
# 7                        Male  14,778  15,614  16,461  15,895  16,856  16,452
# 8                      Female  25,048  25,581  24,956  25,486  26,858  27,394
# 9    HISPANIC ORIGIN AND RACE     NaN     NaN     NaN     NaN     NaN     NaN
# 10     Not Hispanic or Latino  34,971  36,321  36,580  36,793  38,049  37,828
# 11                      White  28,286  29,799  29,704  29,552  30,066  30,222
# 12  Black or African American   4,314   4,113   4,520   4,364   5,044   4,688
# 13                       AIAN     163     219     187     357     366     323
# 14                      NHOPI       *       *       *       *       *     112
# 15                      Asian   1,300   1,287   1,425   1,473   1,608   1,489
# 16          Two or More Races     666     757     584     847     709     995
# 17         Hispanic or Latino   4,855   4,874   4,837   4,589   5,665   6,018
#
#       2014    2015    2016    2017    2018    2019    2020
# 0   43,553  43,421  44,652  46,632  47,635  51,495  52,859
# 1      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    7,014   7,574   7,635   8,849   8,944   9,930  10,238
# 3   36,539  35,847  37,016  37,783  38,691  41,565  42,621
# 4   20,007  20,589  20,903  22,256  22,721  25,279  25,676
# 5   16,531  15,257  16,114  15,527  15,969  16,286  16,945
# 6      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7   16,371  16,785  17,142  18,065  18,308  19,758  19,269
# 8   27,182  26,636  27,510  28,567  29,327  31,737  33,590
# 9      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10  37,795  37,919  38,598  40,603  40,785  44,055  45,115
# 11  30,074  30,387  31,266  32,183  32,210  34,967  35,621
# 12   4,603   4,410   4,171   4,782   4,802   5,174   5,269
# 13     271     270     317     246     333     260       *
# 14     204      89     181     193     198     164       *
# 15   1,653   1,620   1,602   2,000   2,081   2,100   1,995
# 16     989   1,142   1,061   1,198   1,160   1,390   1,689
# 17   5,758   5,502   6,053   6,028   6,850   7,440   7,744

# %%
df2
# Out:
#    Geographic/Socioeconomic Characteristic   20081    2009    2010    2011  \
# 0                                    TOTAL  39,826  41,195  41,417  41,381
# 1                        GEOGRAPHIC REGION     NaN     NaN     NaN     NaN
# 2                                Northeast   7,865   7,587   7,890   6,966
# 3                                  Midwest   9,075   9,169   9,369   9,020
# 4                                    South  13,905  14,604  14,656  15,362
# 5                                     West   8,980   9,835   9,502  10,033
# 6                             COUNTY TYPE2     NaN     NaN     NaN     NaN
# 7                              Large Metro  21,077  21,986  21,967  21,234
# 8                              Small Metro  12,622  13,011  13,151  13,905
# 9                                 Nonmetro   6,127   6,198   6,299   6,243
# 10                               Urbanized   2,554   2,418   2,500   2,589
# 11                          Less Urbanized   2,997   3,222   3,155   3,170
# 12                        Completely Rural     576     558     644     484
# 13                          POVERTY LEVEL3     NaN     NaN     NaN     NaN
# 14                          Less Than 100%   6,402   6,955   7,323   8,428
# 15                                100-199%   8,925   8,885   9,756   9,813
# 16                            200% or More  24,313  25,148  24,187  23,005
# 17                         EDUCATION LEVEL     NaN     NaN     NaN     NaN
# 18                           < High School      nc      nc      nc      nc
# 19                    High School Graduate      nc      nc      nc      nc
# 20         Some College/Associate’s Degree      nc      nc      nc      nc
# 21                        College Graduate      nc      nc      nc      nc
# 22                       HEALTH INSURANCE4     NaN     NaN     NaN     NaN
# 23                                 Private  23,775  24,949  23,693  22,565
# 24                           Medicaid/CHIP   5,287   5,767   6,084   6,664
# 25                                  Other5   8,227   8,587   9,815   9,727
# 26                             No Coverage   7,751   7,446   7,863   8,095
#
#       2012    2013    2014    2015    2016    2017    2018    2019    2020
# 0   43,714  43,846  43,553  43,421  44,652  46,632  47,635  51,495  52,859
# 1      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    7,723   7,701   7,666   7,706   7,910   7,920   8,291   8,608   8,383
# 3    9,173   9,461   9,436   9,167   8,934  10,230  10,329  11,497  11,866
# 4   16,282  16,014  15,877  16,273  16,638  16,847  16,946  18,212  18,616
# 5   10,536  10,670  10,573  10,275  11,169  11,634  12,068  13,178  13,994
# 6      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7   23,221  23,763  23,371  23,474  24,038  25,223  25,715  28,346  27,213
# 8   14,040  13,492  13,260  13,832  14,068  14,626  15,312  15,837  17,946
# 9    6,452   6,591   6,922   6,114   6,546   6,782   6,608   7,312   7,699
# 10   2,646   2,976   2,975   2,666   2,461   2,973   3,153   3,100   3,360
# 11   3,191   3,047   3,260   2,731   3,491   3,214   2,820   3,554   3,629
# 12     615     568     687     717     594     596     635     658     711
# 13     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 14   9,945   9,109   9,358   8,963   8,665   8,766   9,094   8,646   9,810
# 15   9,890   9,721  10,046   9,597  10,727  10,136  10,091  11,258  11,445
# 16  23,669  24,876  23,969  24,720  25,068  27,528  28,246  31,255  31,447
# 17     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 18      nc      nc      nc   5,822   5,538   5,320   5,628   5,505   5,552
# 19      nc      nc      nc  10,621  10,813  10,343  11,110  11,705  13,170
# 20      nc      nc      nc  15,450  15,797  16,525  17,171  18,250  18,339
# 21      nc      nc      nc  11,528  12,504  14,444  13,725  16,034  15,798
# 22     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 23  23,589  25,011  24,456  24,972  26,307  27,933  28,245  30,795  30,239
# 24   7,085   7,282   8,776   9,147   9,845  10,090  10,410  11,149  12,102
# 25  11,458  10,796  11,620  10,971  10,990  10,845  11,142  11,598  13,139
# 26   8,423   7,725   6,206   5,235   4,636   4,901   5,371   5,630   5,824

# %% [markdown]
# #### Data Cleaning
# 1. rename column 20081 to 2008 on df1 and df2
# 2. remove column name [1] on df1 and df2
# 3. drop df1 rows with NaN and insignificant values: [0,1,3,6,9,13,14]
# 4. drop df2 rows with NaN and insignificant values: [0,1,6,12,13,14,15,16,17,22,23,24,25,26]
# 5. concatenate df1 and df2
# 6. rename df row attributes
# 7. remove coma ','
# 8. remove nonsense data 'nc' with NaN
# 9. change data type to numeric data

# %%
df1.rename(columns = {'20081':'2008'}, inplace = True)
df1.rename(columns = {'Demographic Characteristic':''}, inplace = True)
df1 = df1.drop(df1.index[[0,1,3,6,9,13,14]])
df1 = df1.apply(lambda x: x.str.replace('50 or Older', '50+'))

df2.rename(columns = {'20081':'2008'}, inplace = True)
df2.rename(columns = {'Geographic/Socioeconomic Characteristic':''}, inplace = True)
df2 = df2.drop(df2.index[[0,1,6,12,13,14,15,16,17,22,23,24,25,26]])

df = pd.concat([df1,df2], ignore_index = True)

df = df.apply(lambda x: x.str.replace('Northeast', 'Northeast Region'))
df = df.apply(lambda x: x.str.replace('Midwest', 'Midwest Region'))
df = df.apply(lambda x: x.str.replace('South', 'South Region'))
df = df.apply(lambda x: x.str.replace('West', 'West Region'))
df = df.apply(lambda x: x.str.replace('Large Metro', 'Large Metro Resident'))
df = df.apply(lambda x: x.str.replace('Small Metro', 'Small Metro Resident'))
df = df.apply(lambda x: x.str.replace('Nonmetro', 'Non Metro Resident'))

df = df.replace(',','', regex=True)
df = df.apply(lambda x: x.str.replace('nc', ''))
df = df.apply(lambda x: x.str.strip()).replace('', np.nan)

df['2008'] = pd.to_numeric(df['2008']).astype('float')
df['2009'] = pd.to_numeric(df['2009']).astype('float')
df['2010'] = pd.to_numeric(df['2010']).astype('float')
df['2011'] = pd.to_numeric(df['2011']).astype('float')
df['2012'] = pd.to_numeric(df['2012']).astype('float')
df['2013'] = pd.to_numeric(df['2013']).astype('float')
df['2014'] = pd.to_numeric(df['2014']).astype('float')
df['2015'] = pd.to_numeric(df['2015']).astype('float')
df['2016'] = pd.to_numeric(df['2016']).astype('float')
df['2017'] = pd.to_numeric(df['2017']).astype('float')
df['2018'] = pd.to_numeric(df['2018']).astype('float')
df['2019'] = pd.to_numeric(df['2019']).astype('float')
df['2020'] = pd.to_numeric(df['2020']).astype('float')

# %%
df
df.to_csv('../../data/cleaned data/Any Mental Illness 2008-2020.csv')
# Out:
#                                         2008     2009     2010     2011  \
# 0                             18-25   6099.0   6043.0   6151.0   6356.0
# 1                             26-49  20697.0  21455.0  20648.0  19936.0
# 2                               50+  13030.0  13698.0  14618.0  15089.0
# 3                              Male  14778.0  15614.0  16461.0  15895.0
# 4                            Female  25048.0  25581.0  24956.0  25486.0
# 5            Not Hispanic or Latino  34971.0  36321.0  36580.0  36793.0
# 6                             White  28286.0  29799.0  29704.0  29552.0
# 7         Black or African American   4314.0   4113.0   4520.0   4364.0
# 8                             Asian   1300.0   1287.0   1425.0   1473.0
# 9                 Two or More Races    666.0    757.0    584.0    847.0
# 10               Hispanic or Latino   4855.0   4874.0   4837.0   4589.0
# 11                 Northeast Region   7865.0   7587.0   7890.0   6966.0
# 12                   Midwest Region   9075.0   9169.0   9369.0   9020.0
# 13                     South Region  13905.0  14604.0  14656.0  15362.0
# 14                      West Region   8980.0   9835.0   9502.0  10033.0
